# %%
import json
import networkx as nx
import numpy as np

obj = 'crash'
n = 800

with open(f'./qqqhe/test_instances/1589214682686/Instance{obj}/VB=100/n={n}/{obj}_VB=100_n={n}_0.json') as f:
    dict = json.load(f)

# %%
dict['objFuncType']
# Out:
# 'crash'

# %%
G = nx.path_graph(n)
G.add_nodes_from(range(n, 2*n - 1))

for i in range(n, 2*n-1):
    G.add_edge(i, 2*n-2-i)

for i in G.nodes():
    neighbors = list(G.neighbors(i))
    G.nodes[i]['children'] = [x for x in neighbors if x > i]
    G.nodes[i]['parent'] = [x for x in neighbors if x < i]

# Leaves
for i in range(n):
    G.nodes[i+n-1]['l'] = dict['lbVar'][i]
    G.nodes[i+n-1]['u'] = dict['capacity'][i]
    G.nodes[i+n-1]['obj'] = obj
    G.nodes[i+n-1]['param'] = {'a': dict['cost_param_a'][i], 'b': dict['cost_param_b'][i]}

# Inner nodes
for i in range(n-1):
    G.nodes[i]['l'] = dict['lbNested'][n-i-1]
    G.nodes[i]['u'] = dict['ubNested'][n-i-1]
    G.nodes[i]['obj'] = 'zero'
    G.nodes[i]['param'] = {}

# Modify bounds on `x(0)` to reflect bounds for the singleton `{x(0)}`
G.nodes[n-1]['l'] = max(G.nodes[n-1]['l'], dict['lbNested'][0])
G.nodes[n-1]['u'] = min(G.nodes[n-1]['u'], dict['ubNested'][0])

# %%
from utils import greedy

R = G.nodes[0]['l']
yinit = np.ones(n)*R/n
greedy(yinit, G)
# Out:
# (5013,
#  array([15., 37., 28., 54., 27., 48., 58., 53., 41., 40., 53., 54., 64.,
#         41., 41., 63., 30., 30., 55., 51., 65., 47., 39., 35., 32., 35.,
#         31., 65., 36., 62., 56., 28., 52., 44., 30., 47., 48., 23., 37.,
#         41., 26., 32., 35., 24., 24., 39., 37., 56., 23., 46., 28., 38.,
#         42., 54., 51., 46., 46., 51., 53., 42., 57., 53., 25., 16., 45.,
#         43., 40., 23., 42., 35., 42., 47., 45., 39., 66., 47., 36., 38.,
#         27., 20., 37., 41., 46., 35., 38., 47., 55., 29., 53., 17., 45.,
#         28., 31., 33., 34., 21., 42., 35., 31., 34., 54., 42., 45., 53.,
#         52., 38., 46., 32., 48., 38., 35., 43., 17., 49., 50., 24., 51.,
#         33., 55., 48., 53., 42., 65., 60., 43., 53., 64., 51., 57., 65.,
#         27., 64., 16., 52., 50., 37., 34., 27., 49., 20., 30., 21., 60.,
#         47., 44., 27., 56., 62., 40., 40., 64.,  8., 25., 32., 39., 43.,
#         25., 36., 46., 46., 25., 48.,  3., 28., 47., 44., 44., 40., 63.,
#         24., 42., 24., 14., 33., 41., 53., 66., 73., 30., 52., 49., 13.,
#         25., 47.,  7., 51., 46., 73., 39.,  3., 51., 74., 25., 43., 71.,
#         35., 67., 38., 52., 56., 30., 56., 32., 33., 53., 44., 61., 43.,
#         51., 65., 45., 24., 50., 45., 54., 29., 43., 62., 52., 30., 41.,
#         46.,  6., 53., 47., 20., 50., 22., 66., 57., 64., 18., 43., 52.,
#         34., 51., 25., 55., 11., 19., 40., 33., 59., 47., 22., 32., 35.,
#         26., 24., 56., 12., 33., 32., 31., 32., 59., 54., 55., 43., 40.,
#         36., 63., 58., 31., 62., 43., 41., 44., 61., 24., 54., 57., 47.,
#         15., 47., 34., 65., 45., 32., 31., 63., 30.,  9., 36., 47., 49.,
